# %%
from classes import ChargeCollection, SimulatedAnnealing

# %%
iterations = 10_000

N = 12      # = number of charges
c = 0.9     # = cooling rate
max_stepsize = 0.5

simulated_annealing = SimulatedAnnealing(
    charges=ChargeCollection(N),
    max_stepsize=max_stepsize,
    cooling_rate=c
)

simulated_annealing.run(
    iterations=iterations, 
    verbose=True, 
    animate=False, 
    save=False
)

min_energy = simulated_annealing.energy

print('')
print(f"E_min = {min_energy} ({iterations} iterations)")
# Out:
# Iteration 10000/10000, current energy: 59.580630394192724, T: 8.739356258613471e-43
# E_min = 59.580630394192724 (10000 iterations)

# %%
simulated_annealing.charges.plot_charges()

# %%
N = 16
c = 0.9
max_stepsize = 0.5

simulated_annealing = SimulatedAnnealing(ChargeCollection(N), max_stepsize=max_stepsize, cooling_rate=c)
simulated_annealing.run(iterations=iterations, verbose=True)

min_energy = simulated_annealing.energy

print('')
print(f"E_min = {min_energy} ({iterations} iterations)")
# Out:
# Iteration 10000/10000, current energy: 116.55532196124193, T: 8.739356258613471e-43
# E_min = 116.55532196124193 (10000 iterations)

# %%
simulated_annealing.charges.plot_charges()
