# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random
import numpy as np
import math
# import pandas as pdr = np.sqrt(np.random.uniform(0,1,n))

from simulated_annealing import SimulatedAnnealing

# %%
number_charges = 3
max_stepsize = 1
decay_speed = 0.5
dt = 0.01
simulation = SimulatedAnnealing(number_charges,max_stepsize,decay_speed,dt)

simulation.run()
# Out:
# current energy of configuration  2.1134540462700646
# current energy of configuration  3.165503076861381
# current energy of configuration  8.944832361858104
# current energy of configuration  2.5703231279823004
# current energy of configuration  5.110386820679128
# current energy of configuration  6.1113433396347965
# current energy of configuration  2.563035727117107
# current energy of configuration  2.563035727117107
# current energy of configuration  3.308172363191682
# current energy of configuration  3.6360741693852843
# current energy of configuration  3.0099664776740163
# current energy of configuration  237.90510704914323
# current energy of configuration  6.196523994614585
# current energy of configuration  4.650902493141462
# current energy of configuration  5.2685482627661715
# current energy of configuration  6.222534868324039
# current energy of configuration  7.721541763222387
# current energy of configuration  8.4857099706397
# ...
